# %% [markdown]
# ### Title of the book
# 1. This is new notebook
# 1. This is my firsy jupyter book

# %%
import numpy as np
import seaborn as sns

# %%
x = np.array([1,2,3,4,56,7,8,98,9,90,0,90,9,9,8,7,7])

# %%
sns.distplot(x)
